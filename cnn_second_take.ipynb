# %%
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Step 1: Load Expression in-the-wild dataset
# Assuming the dataset is already available in a directory named 'dataset'
# --------------------------------------------------------------------------------------
import pandas as pd
#import cv2
#from sklearn.model_selection import train_test_split

# Step 1: Load Expression in-the-wild dataset (FER2013)
data = pd.read_csv('fer2013.csv')

# Extract image data and labels from the dataset
images = []
labels = []

for idx, row in data.iterrows():
    emotion = row['emotion']
    pixels = row['pixels'].split()
    image = np.array(pixels, dtype='uint8').reshape(48, 48)
    images.append(image)
    labels.append(emotion)

# Convert the lists to NumPy arrays for further processing
images = np.array(images)
labels = np.array(labels)

# Step 2: Preprocessing
# Implement preprocessing techniques such as face detection and alignment

# Example: Resizing images to a fixed size (e.g., 64x64)
image_size = (64, 64)
resized_images = []

for image in images:
    resized_image = cv2.resize(image, image_size)
    resized_images.append(resized_image)

resized_images = np.array(resized_images)

# Normalize pixel values between 0 and 1
resized_images = resized_images.astype('float32') / 255.0

# Split the preprocessed data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(resized_images, labels, test_size=0.2, random_state=42)

# Note: The above code assumes you have the 'fer2013.csv' file in the current directory.
# You may need to adjust the code based on the format and location of your dataset.





# --------------------------------------------------------------------------------------
# Step 2: Preprocessing
# Implement preprocessing techniques such as face detection and alignment

# Step 3: Training and Testing Split
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Step 4: Data Preparation
# Preprocess and prepare the data for CNN input
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
input_shape = (image_width, image_height, num_channels)

# Step 5: Model Creation and Training
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=10, verbose=1)

# Step 6: Model Evaluation
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
accuracy = accuracy_score(y_true, y_pred_classes)
report = classification_report(y_true, y_pred_classes)
print("Accuracy:", accuracy)
print("Classification Report:")
print(report)

# Step 7: Fine-tuning and Hyperparameter Optimization
# Fine-tune the model by adjusting hyperparameters and evaluating the performance

# Step 8: Model Deployment
# Implement an interface or application for real-time facial expression recognition

# Step 9: Documentation and Reporting
# Document the project, methodology, and findings
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 17
#      12 import pandas as pd
#      13 #import cv2
#      14 #from sklearn.model_selection import train_test_split
#      15
#      16 # Step 1: Load Expression in-the-wild dataset (FER2013)
# ---> 17 data = pd.read_csv('fer2013.csv')
#      19 # Extract image data and labels from the dataset
#      20 images = []
#
# ...
